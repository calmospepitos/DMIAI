# %% [markdown]
# # Série d'exercice 1
#
# ## Création de matrices I
#
# Pour les exercices suivants, on vous demande de créer des matrices spécifiques et, pour chacune d'entre elles, d'afficher à l'écran :
# - leur contenu
# - le type sous-jacent
# - son nombre de dimensions
# - sa forme (la taille de chaque dimension)
# - sa taille totale (le nombre de valeurs)
#
# L'objectif n'est pas uniquement de produire ces matrices et ces affichages mais plutôt de comprendre ce qui est produit et le sens des informations données.
#
# **Conseils** : tentez de pratiquer la réutilisabilité de code et n'oubliez pas de consulter vos 3 documents de références pour trouver les informations nécessaires :
# - la documentation de [NumPy](https://numpy.org/doc/stable/)
# - le document de référence Jupyter Notebook sur `NumPy` mis à votre disposition
# - le manuel du cours
#
#
# ### Exercice 1
#
# Créez une matrice 1D de 5 éléments contenant uniquement des zéros, de type entier.
#
#
# ### Exercice 2
#
# Créez une matrice 2D de taille 3 x 4 remplie de la valeur 7, de type flottant 64 bits.
#
#
# ### Exercice 3
#
# Créez une matrice 1D de 10 éléments contenant des valeurs aléatoires entre 0 et 1 (exclu), de type flottant.
#
#
# ### Exercice 4
#
# Créez une matrice identité 2D de taille 5 x 5, de type entier 16 bits non signé (`uint16`).
#
#
# ### Exercice 5
#
# Créez une matrice 3D de taille (2, 3, 4) remplie de la valeur -1, de type entier de 32 bits.
#
#
# ### Exercice 6
#
# Créez une matrice 1D de 7 éléments contenant des valeurs booléennes aléatoires.
#
#
# ### Exercice 7
#
# Créez une matrice 2D de taille (4, 3) contenant des nombres entiers aléatoires entre 1 et 10 (inclus).
#
#
# ### Exercice 8
#
# Créez une matrice 1D de 8 éléments contenant des valeurs espacées linéairement entre 0 et 1 (inclus), de type flottant.
#
#
# ### Exercice 9
#
# Créez une matrice 2D représentant 10 points sous forme de coordonnées 2D où les coordonnées sont une valeur aléatoire dans l'intervalle [-100.0, 100.0]. La matrice possède 10 lignes et 2 colonnes où les colonnes représentent les valeurs x et y respectivement.
#
#
# ### Exercice 10
#
# Créez une matrice 3D de taille (2, 2, 2) remplie de chaînes de caractères "Hello".
#
#
# ### Exercice 11
#
# Avant de réaliser cet exercice, attendez d'avoir vu les nombres complexes dans votre cours de mathématique.
#
# Créez une matrice 2D de taille (3, 5) contenant des nombres complexes aléatoires.

# %%
# Exercices 2
#
# Vos solutions ici
#
# Solution 1


# Solution 2


# Solution 3


# Solution 4


# Solution 5


# Solution 6


# Solution 7


# Solution 8


# Solution 9


# Solution 10


# Solution 11

# %% [markdown]
# # Série d'exercices 2
#
# ## Indexation simple
#
# D'abord, créez ces 3 matrices :
#
# - `data1` : Matrice 1D contenant les nombres entiers de 0 à 9.
# - `data2` : Matrice 2D de taille (3, 3) contenant les nombres entiers de 11 à 19.
# - `data3` : Matrice 2D de taille (4, 4) remplie de uns.
#
#
# ### Exercice 1
#
# Affichez le 5ème élément de `data1`.
#
#
# ### Exercice 2
#
# Affichez l'élément à la 2ème ligne et 3ème colonne de `data2`.
#
#
# ### Exercice 3
#
# Modifiez le 1er élément de `data1` pour qu'il soit égal à 10.
#
#
# ### Exercice 4
#
# Modifiez l'élément à la dernière ligne et dernière colonne de `data3` pour qu'il soit égal à 1.
#
#
# ### Exercice 5
#
# Affichez le 10ème élément de matrice1.
#
#
# ### Exercice 6
#
# Modifiez l'élément à la 3ème ligne et 1ère colonne de matrice2 pour qu'il soit égal à la somme des deux éléments de la 1ère ligne.
#
#
# ### Exercice 7
#
# Inversez la valeur du 4ème élément de `data1` (True devient False, 1 devient -1, etc.).
#
#
# ### Exercice 8
#
# Remplacez le premier élément de chaque ligne de `data3` par 0.
#
#
# ### Exercice 9
#
# Affichez le dernier élément de `data1` en utilisant un index négatif.
#
#
# ### Exercice 10
#
# Faire ce calcul : a = b + c * d
#
# où :
# - a : la coordonnées 1 de `data1`
# - b : la coordonnées 1, 1 de `data2`
# - c : la coordonnées 0, 0 de `data2`
# - d : la coordonnées de la dernière ligne et la dernière colonne de `data3`

# %%
# Exercices 2
#
# Vos solutions ici
#
# Solution 1


# Solution 2


# Solution 3


# Solution 4


# Solution 5


# Solution 6


# Solution 7


# Solution 8


# Solution 9


# Solution 10

# %% [markdown]
# # Série d'exercice 3
#
# ## Création et manipulation de matrices
#
# On désire pratiquer les outils suivants :
# - création de matrices : `arange`, `linspace`, `fromfunction`
# - modification de matrices : `reshape`, `flatten`, `astype`
#
#
# ### Exercice 1
#
# Créez un tableau 1D d'entiers de 0 à 9 (exclu) en utilisant `arange`.
#
#
# ### Exercice 2
#
# Créez un tableau 1D de nombres pairs de 2 à 20 (inclu) en utilisant `arange`.
#
#
# ### Exercice 3
#
# Créez un tableau 1D de 10 valeurs espacées linéairement entre 0 et 1 en utilisant `linspace`.
#
#
# ### Exercice 4
#
# Créez une matrice 2D (3, 3) où chaque élément est la somme de ses indices de ligne et de colonne en utilisant `fromfunction`.
#
#
# ## Exercice 5
#
# Créez une matrice 2D (5, 5) où chaque élément est le produit de ses indices de ligne et de colonne en utilisant `fromfunction`.
#
#
# ### Exercice 6
#
# Créez un tableau 1D de 20 entiers allant de 0 à 19 puis le transformer en une matrice 4x5 en utilisant `reshape`.
#
#
# ### Exercice 7
#
# Créez une matrice 3x4 de nombres flottants aléatoire entre 0.0 et 1.0, la transformer en tableau 1D puis en matrice 2x6 en utilisant `reshape` et `flatten`.
#
#
# ### Exercice 8
#
# Créez une matrice 2D 4x4 d'entiers (valeur 1), la transformer en tableau 1D, puis en matrice 2x8 en utilisant `reshape` et `flatten`.
#
#
# ### Exercice 9
#
# Créez une matrice 2D 5x5 de nombres flottants enrte 0.0 à 10.0, la convertir en entiers en utilisant `astype`.
#
#
# ### Exercice 10
#
# Créez un tableau 2D de 12 x 2 nombres réels aléatoires entre [0, 2[. Le transformer en matrice 3 x 8, puis convertir les éléments en nombres entiers. Finalement, le transformer en matrice 1D en valeurs booléennes.

# %%
# Exercices 3
#
# Vos solutions ici
#
# Solution 1


# Solution 2


# Solution 3


# Solution 4


# Solution 5


# Solution 6


# Solution 7


# Solution 8


# Solution 9


# Solution 10

# %% [markdown]
# # Série d'exercices 4
#
# ## Indexation avec _slicing_
#
# D'abord, créez ces 3 matrices 2D de 12 lignes et 2 colonne chacune représentant de 12 points 2D (des réels de 4 octets) :
#
# - `data1` : valeurs aléatoires entre -10.0 et 10.0
# - `data2` : valeurs aléatoires entre -1.0 et 1.0
# - `data3` : le produit de `data1` par `data2`
#
# Il est important de réaliser que le _slicing_ utilise intrinsèquement la notion de vectorisation `NumPy`.
#
#
# ### Exercice 1
#
# Sélectionner les 5 premières lignes de `data1`.
#
#
# ### Exercice 2
#
# Sélectionner les 3 dernières colonnes de `data2`. (Dans ce cas, cela sélectionne toutes les colonnes car il n'y en a que 2)
#
#
# ### Exercice 3
#
# Sélectionner les lignes d'index pair de `data3`.
#
#
# ### Exercice 4
#
# Sélectionner les lignes d'index impair de `data1`.
#
#
# ### Exercice 5
#
# Inverser les colonnes de `data2`. Autrement dit, les x deviennent les y et vice versa.
#
#
# ### Exercice 6
#
# Chacunes des valeurs de `data1` est égale à la sommes de `data2` et `data3`.
#
#
# ### Exercice 7
#
# Extraire la sous-matrice 5x2 du centre de `data1`.
#
#
# ### Exercice 8
#
# Remplacer les 3 premières lignes de `data2` par les 3 dernières lignes de `data3`.
#
#
# ### Exercice 9
#
# Remplacer les coordonnées impairs de `data1` par les coordonnées pairs de `data2`. Toutefois, on désire inverser l'ordre les x et les y.
#
#
# ### Exercice 10
#
# Remplacer es 5 premières lignes et les 5 dernières lignes de `data1` par les 5 lignes centrales de `data2`.

# %%
# Exercices 4
#
# Vos solutions ici
#
# Solution 1


# Solution 2


# Solution 3


# Solution 4


# Solution 5


# Solution 6


# Solution 7


# Solution 8


# Solution 9


# Solution 10

# %% [markdown]
# # Série d'exercices 5
#
# ## Vectorisation par les opérateurs
#
# D'abord, créez ces 3 matrices 2D de 12 lignes et 2 colonne chacune représentant de 12 points 2D (des réels de 4 octets) :
#
# - `data1` : une matrice 1D de nombres réels avec des valeurs alllant de 0 à 9
# - `data2` :
#     - faire une copie de la matrice `data1` de la première à l'avant dernière valeur (copie référentielle, copie superficielle ou copie profonde?)
#     - effectuer une transformation de la forme d'une matrice 2D de 3 x 3
# - `data3` : produire une matrice 3D de 2 x 2 x 2 avec ces valeurs :
#     - pour la première face : $\begin{bmatrix}
# 10 & 11 \\
# 12 & 13
# \end{bmatrix}$
#     - pour la deuxième face : $\begin{bmatrix}
# 14 & 15 \\
# 16 & 17
# \end{bmatrix}$
#
#
# ### Exercice 1
#
# Additionnez le scalaire 5 à chaque élément de `data2`.
#
#
# ### Exercice 2
#
# Multipliez chaque élément de `data2` par 2.
#
#
# ### Exercice 3
#
# Soustrayez les 2 dernières valeurs de `data1` de la première ligne de `data2`.
#
#
# ### Exercice 4
#
# Assignez aux 8 premières valeurs de `data1` le résultat du quotient de chaque élément des 8 derniers éléments de `data2` par les éléments de `data3`.
#
#
# ### Exercice 5
#
# Calculez le carré de chaque élément de `data3`.
#
#
# ### Exercice 6
#
# Additionnez la sous-matrice de 2 x 2 de `data1` et la transposée de la première dimension de `data3`.
#
#
# ### Exercice 7
#
# Calculez le produit scalaire entre `data1` et un vecteur de 10 uns.
#
#
# ### Exercice 8
#
# Créez une matrice de booléens indiquant les éléments de `data1` qui sont supérieurs à 5.
#
# **Note** : on nomme ce type de matrice, un masque. Un masque peut servir d'information intéressante dans plusieurs autres contextes.
#
#
# ### Exercice 9
#
# Faitse les opérations suivantes :
#
# 1. Utilisez la matrice créée au numéro précédent et la nommer `mask`.
# 2. Faites une copie logiquement inversée et la nommer `inverted_mask`.
# 3. Transformez ces matrices en valeurs entières.
# 4. Modifiez `inverted_mask` par son produit avec `-1`.
# 5. Créez la matrice `final_mask` qui est issu de la somme des deux premières.
# 6. Finalement, faites : `data1 * final_mask`
# 7. Observez bien le résultat obtenu. Tentez de comprendre chacune des étapes et de comprendre la mécanique sous-jacente. Il est important de la comprendre pour pouvoir la généraliser dans divers contexte.
#
#
# ### Exercice 10
#
# Créez cette matrice correspondant aux coordonneés 2D des sommets du triangle isocèle suivant :
#
# $\texttt{triangle} = \begin{bmatrix}
# -1.0 & 0.0 \\
#  1.0 & 0.0 \\
#  0.0 & 1.0
# \end{bmatrix}$
#
# Calculer le centroïde de ce triangle (la coordonnée moyenne équivalente à la moyenne des x et la moyenne des y). Vous devriez obtenir une matrice de 2 valeurs.
#
# Finalement, calculer, dans une nouvelle matrice de taille 3, la distance entre chacun des sommets du triangle et le centroïde.

# %%
# Exercices 5
#
# Vos solutions ici
#
# Solution 1


# Solution 2


# Solution 3


# Solution 4


# Solution 5


# Solution 6


# Solution 7


# Solution 8


# Solution 9


# Solution 10

# %% [markdown]
# # Série d'exercices 6
#
# ## Exercice d'indexation par sélection
#
# Vous avez les données suivantes qui sont disponibles au début de l'exercice :
# - le nombre d'année d'ancienneté de chaque employé
# - le salaire horaire de tous les employés
# - le nombre d'heures travaillées par semaine
# - le nombre de semaine par année
#
# Les listes de noms, d'ancienneté et de salaire horaire sont synchrones. C'est-à-dire que l'ordre dans la liste importe et représente le même employé.
#
# Les exercices suivant visent la pratique des fonctions universelles et de `ndarray` de `Python`.
#
#
# ### Exercice 1
#
# Sélectionnez les ancienneté des employés ayant une ancienneté supérieure à 5 ans.
#
#
# ### Exercice 2
#
# Sélectionnez les noms des employés ayant un salaire horaire inférieur à 20$ de l'heure.
#
#
# ### Exercice 3
#
# Sélectionnez les noms des employés ayant une ancienneté supérieure à 5 ans et un salaire horaire supérieur à 30$ de l'heure.
#
#
# ### Exercice 4
#
# Calculez le salaire annuel moyen des employés ayant une ancienneté de plus de 3 ans.
#
#
# ### Exercice 5
#
# Produire le minimum, la moyenne et le maximum des salaires annuels des employés ayant une ancienneté entre 3 et 7 ans.
#
#
# ### Exercice 6
#
# Calculez la moyenne et l'écart-type des salaires hebdomadaires des employés ayant moins de 5 ans d'ancienneté et plus de 10 ans d'ancienneté.
#
#
# ### Exercice 7
#
# Sélectionnez le nom des employés ayant un salaire horaire supérieur au salaire horaire médian et une ancienneté supérieure à la moyenne.
#
#
# ### Exercice 8
#
# Faites deux tries où les employés sont affiché par leur nom :
# - Triez les employés par ordre croissant d'ancienneté
# - Triez les employés par ordre décroissant de salaire annuel
#
#
# ### Exercice 9
#
# Créez un tableau de 2 colonnes où :
# - la première possède le nom
# - la seconde indique si chaque employé a un salaire horaire supérieur au salaire horaire moyen
#
#
# ### Exercice 10
#
# Donnez une augmentation salariale de 3.5% seulement aux employés répondant aux trois critères suivants :
# - le nom possède au moins une occurence de la lettre `a` (minuscule ou majuscule)
# - l'ancienneté est un nombre pair
# - le salaire horaire est inférieur au salaire se trouvant au centre de l'intervalle défini par le plus petit et du plus grand salaire
#
# _Note_ : voir les fonctions de manipulation de chaîne de caractères `np.char.lower(...)` et `np.char.find(...)`.

# %%
# Données mises à votre disposition pour les exercices

# noms des employés
employe: tuple[str] = ('Alex', 'Anna', 'Ben', 'Charlie', 'Emma', 'Eva', 'Leo', 
                       'Liam', 'Lily', 'Louis', 'Max', 'Mia', 'Noah', 'Olivia', 
                       'Oscar', 'Rose', 'Sam', 'Sarah', 'Tom', 'Zoe')

 # ancienneté des employés en années
anciennete = [2, 5, 3, 1, 8, 4, 6, 2, 7, 3, 4, 10, 5, 9, 6, 3, 8, 9, 7, 6]

# salaire horaire des employés en dollard
salaire_horaire: tuple[float] = ( 9.50, 33.50, 30.25, 10.75, 41.50, 16.75, 18.00, 
                                 15.50, 21.00, 15.25, 21.50, 38.00, 25.25, 42.00, 
                                 25.00, 18.75, 37.25, 38.50, 40.00, 41.00)

# nombre d'heures travaillées par semaine
heures_par_semaine = 37.5

# nombre de semaines payées par année
semaine_par_annee = 52



# Exercices 6
#
# Vos solutions ici
#
# Solution 1


# Solution 2


# Solution 3


# Solution 4


# Solution 5


# Solution 6


# Solution 7


# Solution 8


# Solution 9


# Solution 10

# %% [markdown]
# # Série d'exercices 7
#
# ## Vectorisation par les fonctions universelles ou de `ndarray`
#
# Pour cette série d'exercices, on réutilise les mêmes données que celles données précédemment.
#
#
# ### Exercice 1
#
# Calculer la masse salariale et le salaire moyen (salaire horaire dans les deux cas) :
# - Utilisez la fonction `np.sum(...)` et ensuite `np.ndarray.sum(...)` pour calculer la masse salariale hebdomadaire totale.
# - Utilisez la fonction `len(...)` pour obtenir le nombre d'employés et calculez le salaire horaire moyen en divisant la masse salariale par le nombre d'employés.
#
#
# ### Exercice 2
#
# Calculer lu salaire annuel médian en utilisant 2 approches :
# - sans `NumPy` (trier le tableau original et extraire la valeur au centre)
# - avec `NumPy` avec `np.median(...)`
#
#
# ### Exercice 3
#
# Produire une mini analyse satatistique en indiquant des informations financières **annuelle** :
# - la nombre d'employé
# - la masse salariale
# - le salaire le plus bas
# - le salaire le plus élevé
# - la moyenne salariale
# - l'écart type entre les salaires
#
#
# ### Exercice 4
#
# Comptage des employés à salaire horaire bas et élevé. Identifier le nombre d'employés gagnant un salaire horaire :
# - inférieur à 15.50 $
# - au moins 30.00 $
#
#
# ### Exercice 5
#
# Calcul les coûts annuels du point de vu de l'employeur pour quatre scénarios d'augmentation salariale :
# 1. 2% à tous les employés
# 2. 5% à tous qui gagnent moins que la moyenne salariale
# 3. en deux parties :
#    - 1000.00$ à tous les employés gagnant moins de 1 écart-type de plus à la moyenne
#    - 12.5% à tous ceux gagnant plus de 2 écarts-type au dessus de la moyenne
# 4. pour chaque employé, un pourcentage d'augmentation égal à sa proportion dans la masse salariale de l'entreprise (par exemple, Paul gagne 50000$ par année et son salaire correspond à 3.8% de tous les salaires, alors il a une augmentation de 3.8%)
#
#
# ### Exercice 6
#
# Produire une matrice des salaires normalisés.
#
#
# ### Exercice 7
#
# Créez une matrice de $n \times 2$ où $n$ est le nombre d'employés et 2 les colonnes où vous avez, dans la première colonne, les salaires annuels et, ensuite dans la 2e colonne, le nombre d'année d'ancienneté. Cette matrice est représentée par des nombres réels.
#
# On désires, pour chacune des demandes suivantes, produire en une seule opération :
# - la masse salariale de l'entreprise et le nombre total d'années d'ancienneté cumulées par tous les employés
# - pour chaque employé, le montant gagné annuellement depuis qu'il travail pour l'entreprise
#
# _Note_ : voir l'option `axis` des fonctions `np.sum(...)` et `np.prod(...)` (comprendre le concept et savoir l'appliquer là où pertinent).
#
#
# ### Exercice 8
#
# Donnez une augmentation salariale seulement pour certains employés. Les critères suivants sont à respecter :
# - l'augmentation doit être doit être attribuée sur le taux horaire des employés concernés
# - on considère uniquement les employés répondant à ces critères :
#   - les employés qui ont au maximum 3 ans d'ancienneté ou plus de 9 ans
#   - le montant de l'augmentation est la somme de :
#     - 5% de la moyenne de tous les employés
#     - 5% de la médiane de tous les employés
#
#
# ### Exercice 9
#
# Donnez le nom des 5 employés ayant le meilleur salaire. On désire afficher le nom par ordre décroissant de salaire.
#
# _Note_ : explorez la fonction `np.argsort` entre autre.
#
#
# ### Exercice 10
#
# Utilisez la fonction `np.digitize(...)` pour regrouper les employés en huit tranches d'ancienneté :
# - 0-3 ans
# - 4-6 ans
# - 7-9 ans
# - 10-12 ans
# - 13-15 ans
# - 16-18 ans
# - 19-21 ans
# - 22 ans et plus
#
# Utilisez ensuite la fonction `np.bincount(...)` pour compter le nombre d'occurence pour chaque catégorie.
#
# Finalement, faites la moyenne salariale pour chacune des 4 catégories. Une boucle explicite sera nécessaire ici. Il est important de comprendre pourquoi.

# %%
# Exercices 7
#
# Vos solutions ici
#
# Solution 1


# Solution 2


# Solution 3


# Solution 4


# Solution 5


# Solution 6


# Solution 7


# Solution 8


# Solution 9


# Solution 10
# Out:
# 20

# %% [markdown]
# # Série d'exercices 8
#
# ## Résolution de problèmes géométriques
#
# Réaliser toutes les fonctions données plus bas.

# %%
import numpy as np


# --------------------------------------------------------------------
def distance(point1: np.ndarray[np.float32], point2: np.ndarray[np.float32]) -> float:
  """
  Calcule la distance euclidienne entre deux points.

  Args:
    point1: Un tableau numpy de forme (2,) représentant les coordonnées (x, y) du premier point.
    point2: Un tableau numpy de forme (2,) représentant les coordonnées (x, y) du deuxième point.

  Returns:
    La distance euclidienne entre les deux points.
  """
  # Votre code ici
  pass


# --------------------------------------------------------------------
def perimetre_triangle(sommets: np.ndarray[np.float32]) -> float:
  """
  Calcule le périmètre d'un triangle.

  Args:
    sommets: Un tableau numpy de forme (3, 2) représentant les coordonnées (x, y) des trois sommets du triangle.

  Returns:
    Le périmètre du triangle.
  """
  # Votre code ici


# --------------------------------------------------------------------
def aire_triangle(sommets: np.ndarray[np.float32]) -> float:
  """
  Calcule l'aire d'un triangle en utilisant la formule de Héron.

  Args:
      sommets: Un tableau numpy de forme (3, 2) représentant les coordonnées (x, y) des trois sommets du triangle.

  Returns:
      L'aire du triangle.
  """
  # Votre code ici
  pass


# --------------------------------------------------------------------
def est_dans_rectangle(point: np.ndarray[np.float32], coin_inf_gauche: np.ndarray[np.float32], coin_sup_droit: np.ndarray[np.float32]) -> bool:
  """
  Détermine si un point est à l'intérieur d'un rectangle aligné avec le système d'axes.

  Args:
    point: Un tableau numpy de forme (2,) représentant les coordonnées (x, y) du point.
    coin_inf_gauche: Un tableau numpy de forme (2,) représentant les coordonnées (x, y) du coin inférieur gauche du rectangle.
    coin_sup_droit: Un tableau numpy de forme (2,) représentant les coordonnées (x, y) du coin supérieur droit du rectangle.

  Returns:
      True si le point est à l'intérieur du rectangle, False sinon.
  """
  # Votre code ici
  pass



# --------------------------------------------------------------------
def cercle_circonscrit(coin_inf_gauche: np.ndarray[np.float32], coin_sup_droit: np.ndarray[np.float32]) -> tuple[np.ndarray[np.float32], float]:
  """
  Calcule le centre et le rayon d'un cercle circonscrit à un rectangle.

  Args:
    coin_inf_gauche: Un tableau numpy de forme (2,) représentant les coordonnées (x, y) du coin inférieur gauche du rectangle.
    coin_sup_droit: Un tableau numpy de forme (2,) représentant les coordonnées (x, y) du coin supérieur droit du rectangle.

  Returns:
    Un tableau ndarray de forme (3,) représentant le cercle circonscrit. Les éléments sont :
      - les coordonnées (x, y) du centre
      - le rayon
  """
  # Votre code ici
  pass


# --------------------------------------------------------------------
def intersection_droites(ligne1: np.ndarray[np.float32], ligne2: np.ndarray[np.float32]) -> np.ndarray[np.float32]:
  """
  Calcule le point d'intersection de deux droites.

  Voir cette technique de calcul présentée sur le site de [Wofram](https://en.wikipedia.org/wiki/Line%E2%80%93line_intersection).
  
  Args:
    ligne1: Un tableau (2, 2) contenant deux points définissant la première droite. Les points sont sur les lignes. 
    ligne2: Un tableau (2, 2) contenant deux points définissant la deuxième droite. Les points sont sur les lignes. 

  Returns:
    Un tableau numpy de forme (2,) représentant les coordonnées (x, y) du point d'intersection.
    Retourne None si les droites sont parallèles.
  """
  # Votre code ici
  pass


# --------------------------------------------------------------------
def angle_vecteurs(vecteur1: np.ndarray[np.float32], vecteur2: np.ndarray[np.float32]) -> float:
  """
  Calcule l'angle entre deux vecteurs.

  Args:
    vecteur1: Un tableau numpy de forme (2,) représentant le premier vecteur.
    vecteur2: Un tableau numpy de forme (2,) représentant le deuxième vecteur.

  Returns:
    L'angle entre les deux vecteurs en radians.
  """
  # Votre code ici
  pass


# --------------------------------------------------------------------
def centroide_nuage_points(nuage: np.ndarray[np.float32]) -> np.ndarray[np.float32]:
  """
  Calcule le centroïde d'un nuage de points.

  Args:
    nuage: Un tableau numpy de forme (n, 2) représentant les coordonnées (x, y) des n points.

  Returns:
    Un tableau numpy de forme (2,) représentant les coordonnées (x, y) du centroïde.
  """
  # Votre code ici
  pass



# --------------------------------------------------------------------
def analyse_cercles(cercles: np.ndarray[np.float32]) -> np.ndarray[np.float32]:
  """
  Analyse un ensemble de cercles pour déterminer le cercle qui a la plus grande aire.

  Args:
    cercles: Un tableau numpy de forme (n, 3) où chaque ligne contient les coordonnées (x, y) du centre et le rayon d'un cercle.

  Returns:
    Un tableau numpy de forme (n, 4) où chaque ligne représente des informations pour chaque cercle. Les colonnes sont :
      - l'orientation du centre du cercle par rapport aux absisses, en radians
      - la distance du centre du cercle à l'origine (au point (0, 0))
      - le périmètre du cercle
      - l'aire du cercle

    On remarque que les deux premières colonnes forment la coordonnée polaire du centre du cercle. 
  """
  # Votre code ici
  pass


# --------------------------------------------------------------------
def analyse_somme_rectangles(rectangles: np.ndarray[np.float32]) -> np.ndarray[np.float32]:
  """
  Analyse un ensemble de rectangles pour déterminer la somme de plusieurs caractéristiques.

  Args:
    rectangles: Un tableau numpy de forme (n, 4) où chaque ligne contient :
      - les coordonnées (x, y) du coin inférieur gauche
      - les coordonnées (x, y) du coin supérieur droit

  Returns:
    Un tableau numpy de forme (3,) où chaque données représente sont :
      - la somme des périmètres
      - la somme des aires
      - la somme de la longueurs des diagonales
  """
  # Votre code ici
  pass

# %% [markdown]
# # Série d'exercices 8
#
# ## Résolution de problèmes géométriques
#
# Réaliser toutes les fonctions données plus bas.
#
#
# ### Exercice 1 : Analyse météorologique
#
# Un météorologue reçoit des données de températures mesurées toutes les heures sur une année complète. Ces données sont stockées dans un tableau numpy de taille (365, 24), chaque ligne représentant un jour de l'année et chaque colonne une heure.
#
# **Objectif**
#
# Calculez :
# - la température minimale, moyenne et maximale observée sur l'année
# - pour chaque jour, pour chacun des 365 jours :
#   - la température moyenne de la journée
#   - la température moyenne de la nuit [23h00, 05h00[
#   - la température moyenne du matin [05h00, 11h00[
#   - la température moyenne du jour [11h00, 17h00[
#   - la température moyenne du soir [17h00, 23h00[
# - la température moyenne par heure pour chacune des 24 heures
#
# Identifiez les jours où la température maximale a dépassé 30°C.
#
# **Solution attendue**
#
# Utilisez les fonctions `numpy` `mean`, `max`, `min`, et des indexations par sélection pour effectuer ces analyses efficacement.
#
#
# ### Exercice 3 : Simulation de processus aléatoire
#
# Un économiste souhaite modéliser le cours d'une action sur une période de 100 jours. Il utilise un modèle de marche aléatoire avec une variation quotidienne de $\pm 2\%$ autour de la valeur du jour précédent.
#
# **Objectif**
#
# Initialisez le cours de l'action à 100 et simulez les variations de cours sur 100 jours.
#
# Affichez la valeur finale de l'action ainsi que la valeur maximale et minimale atteintes pendant la période.
#
# Affichez la moyenne des variations quotidiennes.
#
# **Solution attendue**
#
# Utilisez `numpy` `random` pour générer des variations aléatoires et appliquez-les de manière cumulative avec `cumprod` pour simuler la marche aléatoire.
